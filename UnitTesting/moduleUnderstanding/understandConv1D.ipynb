# %%
import torch
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, "C:/Users/asalvi/Documents/Ameya_workspace/DiffusionDataset/ConeCamAngEst/training/") 
from modules.conv1d import Conv1dBlock  # Import Conv1D module

# %%
x = torch.sin(torch.linspace(0, 2 * torch.pi, 100)).unsqueeze(0).unsqueeze(0)  # (1, 1, 100)
model = Conv1dBlock(1, 1, kernel_size=3)

with torch.no_grad():
    out = model(x)

# %%
plt.plot(x[0,0].numpy(), label="Input")
plt.plot(out[0,0].numpy(), label="Output")
plt.legend()
plt.show()
